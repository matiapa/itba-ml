# %% [markdown]
# # Resultados usando AdaBoost classifier

# %%
import AdaBoost as ab

# %% [markdown]
# ## Análisis de mejor configuración

# %% [markdown]
# ### Learning rate

# %%
ab.learning_rate_analysis()

# %% [markdown]
# ### Número de estimadores

# %%
ab.estimators_analysis()

# %% [markdown]
# ## Accuracy

# %%
X, y = ab.load_data(undersample=False)
ab.accuracy(X, y)
# Out:
# Accuracy: 92.37 %

# %% [markdown]
# ## Metrics

# %%
X, y = ab.load_data()
ab.metrics_results(X, y)
# Out:
# {'tp': 141, 'fp': 56, 'tn': 8802, 'fn': 733}
# Accuracy: 91.89 %
# Precision: 71.57 %
# Recall: 16.13 %
# F1: 26.33 %
# True positive rate: 16.13 %
# False positive rate: 0.63 %

# %%
ab.metrics_learning_rate(['fp_rate', 'accuracy', 'precision'], samples=10)
# Out:
# 100%|██████████| 6/6 [03:30<00:00, 35.04s/it]

# %%
ab.metrics_estimators(['fp_rate', 'accuracy', 'precision'], samples=10)
# Out:
# 100%|██████████| 10/10 [06:28<00:00, 38.81s/it]

# %% [markdown]
# # Undersampling

# %%
X, y = ab.load_data(undersample=True)
ab.metrics_results(X, y)
ab.accuracy(X, y)
# Out:
# Accuracy: 77.14 %
# Precision: 78.18 %
# Recall: 76.65 %
# F1: 77.41 %
# True positive rate: 76.65 %
# False positive rate: 22.34 %
# Accuracy: 77.07 %

# %% [markdown]
# # Oversample

# %%
X, y = ab.load_data(oversample=True)
ab.metrics_results(X, y)
ab.accuracy(X, y)
# Out:
# (88856, 12) (88856,)
# 0    44428
# 1    44428
# Name: is_promoted, dtype: int64
# Accuracy: 84.13 %
# Precision: 85.22 %
# Recall: 82.59 %
# F1: 83.88 %
# True positive rate: 82.59 %
# False positive rate: 14.33 %
# Accuracy: 82.51 %
